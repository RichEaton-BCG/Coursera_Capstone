# %% [markdown]
# <font color=blue>
#     <h1> Battle of Neighborhoods </h1></font>
# <font color=black><h3>Created by Rich Eaton </h3>
# </font>

# %% [markdown]
# <Font color = blue><h2> Part One -- NY vs. Toronto</h2></Font>
#
# When I first started to do the review of the cities it becamse clear t me that both Tronto and NY were very much the same.
# So when asked to compare neighborhoods, I thought it might be great to take a look at certain areas that might have some distinct similarities.
# I wanted to look at a resenidential area of comparable income and see how these two areas might match up.

# %% [markdown]
# <B>Business Problem</B> — A restaurant chain had ask me to find a location for their next store. They gave me the following details.
#
# It needed to be in Toronto
# The menu was going to be American Steakhouse
# So with this information I went off in search of a location.
#
# <B>The Process</B> —  Get Data –> Understand Data –> discover potential locations –> Disclose what else is close to the area –> Map it.
#
# First I had to find out some information about Toronto, There are a few web sites where data is available freely. I used two that helped significantly
#
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/prof/details/page.cfm?Lang=E&Geo1=CSD&Code1=3520005&Geo2=PR&Code2=01&Data=Count&SearchText=&SearchType=Begins&SearchPR=01&B1=Income&TABID=1
#
# The first provided me the postal codes for the city of Toronto so I could breakdown the neighborhoods. The second file was from their 2016 census, which was used to find the median incomes for these postal codes. After all no sense putting a restaurant where people don’t have disposable income to actually go to it.
#
# The overall process produced both the data for review of not only the site but also of the other venues near the proposed location.

# %% [markdown]
# <Font color= grey><h5> Tronto Data </h5></Font>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 0      M3A        North York         Parkwoods  43.753259 -79.329656
# 1      M4A        North York  Victoria Village  43.725882 -79.315572
# 2      M5A  Downtown Toronto      Harbourfront  43.654300 -79.360600
# 3      M6A        North York  Lawrence Heights  43.718518 -79.464763
# 4      M6A        North York    Lawrence Manor  43.718518 -79.464763

# %%
# Matplotlib and associated plotting modules

# import k-means from clustering stage

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1f             |       h516909a_0         2.1 MB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
# ...

# %%
latitude = 43.6548
longitude = -79.3883

map_tronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, Neighbourhood in zip(df_location['Latitude'], df_location['Longitude'], df_location['Borough'], df_location['Neighbourhood']):
    label = '{}, {}'.format(Neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tronto)  
    
map_tronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2> Review of Tronto Data</h2>

# %%
body = client_c4caad9db9a24ba3bcff72c5bf68697a.get_object(Bucket='capstoneproject-donotdelete-pr-by4a3z2flww3ig',Key='Tronto Income.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_tron_inc = pd.read_excel(body)
df_tron_inc.head()
# Out:
#   Postcode          Borough        Neighbourhood  Latitude  Longitude  \
# 0      M4G        East York              Leaside  43.70906 -79.363452
# 1      M5M       North York         Bedford Park  43.73330 -79.419700
# 2      M5M       North York  Lawrence Manor East  43.73330 -79.419700
# 3      M4N  Central Toronto        Lawrence Park  43.72802 -79.388790
# 4      M4T  Central Toronto           Moore Park  43.68960 -79.383200
#
#    Median Income
# 0         133703
# 1         135475
# 2         135475
# 3         156174
# 4         150692

# %% [markdown]
# <Font color= grey><h5> New York Data </h5></Font>

# %%
body = client_c4caad9db9a24ba3bcff72c5bf68697a.get_object(Bucket='capstoneproject-donotdelete-pr-by4a3z2flww3ig',Key='NYC Income.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_ny_inc = pd.read_excel(body)
df_ny_inc.head()
# Out:
#    #  PostalCode   Latitude  Longitude                City  Population  Income
# 0  1       10007  40.713973 -74.008336  New York, New York        3522  112947
# 1  2       10280  40.708501 -74.016828  New York, New York        6614  108536
# 2  3       10162  40.769298 -73.949942  New York, New York        1726  108416
# 3  4       10004  40.691870 -74.014109  New York, New York        1225  101868
# 4  5       10069  40.775551 -73.989689  New York, New York        1403   88091

# %% [markdown]
# <h2> Review of Tronto Data</h2>

# %%
ny_lat = 40.7831
ny_lon = -73.9712
map_ny = folium.Map(location=[ny_lat, ny_lon], zoom_start=10)

# add markers to map
for lat, lng, PostalCode, City in zip(df_ny_inc['Latitude'], df_ny_inc['Longitude'], df_ny_inc['PostalCode'], df_ny_inc['City']):
    label = '{}, {}'.format(PostalCode, City)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ny)  
    
map_ny
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <Font color = blue><h2>Part Two -- We have two requests</h2></Font>
#
# <Font color = Green><h4> Requests </h4></Font>
#  - The first request is from a resturant chain that is looking for a new location for their next store.
#  - The second comes from a local contractor who is wanting to establish an office and wondering if we might have a recommendation.

# %% [markdown]
# <Font color = Green><h4> Request One </h4></Font>
# For the first request we are considering a neighboirhood to place our resturant.
#
# <Font color = Red><h4> ** Assumption ** </h4></Font>
#  - The area should have moderate mean income, since these families tend to have more disposible income
#  - The resturant chain is an American steakhouse

# %%
from geopy.geocoders import Nominatim

#libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
CLIENT_ID = 'AY301NC0HTK33E1ESEWQQ51IYUA2D00NGGQUOKLQL110NLR0' # your Foursquare ID
CLIENT_SECRET = 'DCYSCMTWAMYALPDYBACQU0HOFGXZLXUDZI0Q02LB25RAZ42W' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30

# %%
#address = '102 North End Ave, New York, NY'
#geolocator = Nominatim(user_agent="foursquare_agent")
#location = geolocator.geocode(address)
latitude = 43.72802
longitude = -79.388790
print(latitude, longitude)
# Out:
# 43.72802 -79.38879

# %%
search_query = 'Steak'
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

venues = results['response']['venues']
df_locations = json_normalize(venues)
df_locations.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
#
#                          id location.address location.cc location.city  \
# 0  57f6d0ae498e3aa877aff6c7              NaN          CA           NaN
# 1  4aeb445df964a52059c021e3   3438 Yonge St.          CA       Toronto
#
#   location.country      location.crossStreet  location.distance  \
# 0           Canada                       NaN               1340
# 1           Canada  btwn Deloraine & Melrose               1415
#
#                            location.formattedAddress  \
# 0                               [ON M4N 2M8, Canada]
# 1  [3438 Yonge St. (btwn Deloraine & Melrose), To...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.732826, 'lng':...     43.732826
# ...

# %% [markdown]
# <Font Color = Blue><h3>  Results </h3></Font>
# Now we have found some other steak houses however they are a distance away. So this seems that a location within this zip code
# would be a suitable location for the new chain store to be located. There is a good population close by with dispensible
# income.

# %%
df_locationn = df_locations.filter(['location.lat', 'location.lng', 'location.postalCode', 'name'], axis = 1)
df_locationn.rename(columns={"location.lat": "Latitude", "location.lng": "Longitude", "location.postalCode": "postalcode"}, inplace = True)
df_locationn.head()
# Out:
#     Latitude  Longitude postalcode                            name
# 0  43.732826  -79.40407    M4N 2M8      Blackod Steak & Fish House
# 1  43.733654  -79.40457    M4N 2N2  Wildfire Steakhouse & Wine Bar

# %%
# Mapping a location and adding close competitors

latitude = 43.646184
longitude = -79.391032

map_tronto = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for Latitude, Longitude, postalcode, name in zip(df_locationn['Latitude'], df_locationn['Longitude'], df_locationn['postalcode'], df_locationn['name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=True).add_to(map_tronto)
    folium.CircleMarker([43.646184, -79.391032], radius=5, popup='New Location',color='red',fill= False,parse_html=True).add_to(map_tronto)
    
map_tronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <Font color = Blue> <h3> We have identified the location ! </h3></Font>
# So now that we have the locatiion lets see what FourSquare can tellus about the surrounding area.

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()

neighbors = results['response']['venues']
df_traffic = json_normalize(neighbors)
df_neighbors = df_traffic.filter(['location.lat', 'location.lng', 'location.postalCode', 'name'], axis = 1)
df_neighbors.rename(columns={"location.lat": "Latitude", "location.lng": "Longitude", "location.postalCode": "postalcode"}, inplace = True)
df_neighbors.head()
df_neighbors
# Out:
#      Latitude  Longitude postalcode  \
# 0   43.646245 -79.391459        NaN
# 1   43.646199 -79.391484    M5V 1J9
# 2   43.646386 -79.391584    M5V 1J9
# 3   43.646091 -79.389068        NaN
# 4   43.646043 -79.390992    M5V 1J9
# 5   43.646718 -79.387209    M5V 3G2
# 6   43.647439 -79.390855        NaN
# 7   43.645756 -79.390904    M5V 1H3
# 8   43.646342 -79.390063    M5V 3X5
# 9   43.647615 -79.388381    M5V 3M2
# 10  43.646033 -79.391294        NaN
# 11  43.645633 -79.391225    M5V 9G9
# 12  43.646301 -79.393811        NaN
# 13  43.646450 -79.391759    M5V 1J9
# 14  43.646330 -79.390694    M5V 1J5
# 15  43.646416 -79.390030    M5V 1J5
# 16  43.646331 -79.391373    M5V 1J9
# 17  43.646443 -79.390044    M5V 1J5
# 18  43.646138 -79.390908    M5V 1P7
# 19  43.646333 -79.390717    M5V 1J5
# 20  43.646280 -79.391198    M5V 1J5
# 21  43.646150 -79.389872    M5V 3X5
# 22  43.646345 -79.390824    M5V 1J5
# 23  43.646100 -79.391595    M5V 1J9
# 24  43.646379 -79.390139        NaN
# ...

# %% [markdown]
# <H2> Conclusion </H2>

# %% [markdown]
# So as you can see the location for the new store is an area that is surrounded by other venues however there are
# few competiors nearby. The location has 2 hotels within walking distance making this an ideal place for the store.
